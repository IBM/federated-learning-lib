# %% [markdown]
# # Fairness in IBM FL: Scikitlearn Logistic Classification

# %% [markdown]
# ## Outline:
# - [Add conda environment to Jupyter Notebook](#setup)
# - [FL and Fairness](#intro)
# - [Parties](#Parties)
#     - [Party Configuration](#Party-Configuration)
#     - [Party Setup](#Party-Setup)
# - [Register All Parties Before Starting Training](#Register-All-Parties-Before-Starting-Training)
# - [Visualize Results](#Visualize-Results)
# - [Shut Down](#Shut-Down)

# %% [markdown]
# ## Add conda environment to Jupyter Notebook <a name="setup"></a>
#
# Please ensure that you have activated the `conda` environment following the instructions in the project README.
#
# Once done, run the following commands in your terminal to install your conda environment into the Jupyter Notebook:
#
# 1. Once you have activated the conda environment, install the `ipykernel` package: `conda install -c anaconda ipykernel`
#
# 2. Next, install the `ipykernel` module within Jupyter Notebook: `python -m ipykernel install --user --name=<conda_env>`
#
# 3. Finally, restart the jupyter notebook once done. Ensure that you are running this Notebook from `<project_path>`, where project_path is the directory where the IBMFL repository was cloned.
#
# When the Notebook is up and running it may prompt you to choose the kernel. Use the drop down to choose the kernel name same as that chosen when running `conda activate <conda_env>`. If no prompt shows up, you can change the kernel by clicking _Kernel_ > _Change kernel_ > _`<conda_env>`_.

# %% [markdown]
# ## Federated Learning (FL) <a name="intro"></a>
#
# **Federated Learning (FL)** is a distributed machine learning process in which each participant node (or party) retains their data locally and interacts with  other participants via a learning protocol. In this notebook, we demonstrate the adaption and usage of popular bias mitigation techniques for FL. We examine bias from the perspective of social fairness, as opposed to contribution fairness.
#
# Bias mitigation approaches in machine learning mainly measure and reduce undesired bias with respect to a *sensitive attribute*, such as *age* or *race*, in the training dataset.
#
# We utilize [IBM FL](https://github.com/IBM/federated-learning-lib) to have multiple parties train a classifier to predict whether a person in the [Adult dataset](http://archive.ics.uci.edu/ml/datasets/Adult) makes over $50,000 a year. We have adapted 2 centralized fairness methods, Reweighing and Prejudice Remover, into 3 federated learning bias mitigation methods: Local Reweighing, Global Reweighing with Differential Privacy, and Federated Prejudice Removal.
#
# For a more technical dive into IBM FL, refer the whitepaper [here](https://arxiv.org/pdf/2007.10987.pdf).

# %% [markdown]
# ## Fairness Techniques <a name="fairness"></a>
#
# [Reweighing](https://link.springer.com/article/10.1007/s10115-011-0463-8) is a centralized pre-processing bias mitigation method, which works primarily by attaching weights to samples in the training dataset. This method accesses the entire training dataset and computes weights as the ratio of the expected probability to the observed probability of the sample, calculated based on the sensitive attribute/label pairing in question. We adapt this centralized method into two federated learning techniques, Local Reweighing and Global Reweighing with Differential Privacy.
#
# **Local reweighing**: To fully protect parties' data privacy, each party computes reweighing weights locally based on its own training dataset during pre-processing and then uses the reweighing dataset for its local training. Therefore, parties do not need to communicate with the aggregator or reveal their sensitive attributes and data sample information.
#
# **Global Reweighing with Differential Privacy**: If parties agree to share sensitive attributes and noisy data statistics, parties can employ this fairness method. During the pre-processing phase, the aggregator will collect statistics such as the noisy number of samples with privileged attribute values, compute global reweighing weights  based on the collected statistics, and share them with parties. By adjusting the amount of noise injected via epsilon, parties can control their data leakage while still mitigating bias.
#
# [Prejudice Remover](https://github.com/algofairness/fairness-comparison/tree/master/fairness/algorithms/kamishima) is an in-processing bias mitigation method 440 proposed for centralized ML, which works by adding a fairness-aware regularizer to the regular logistic loss function. We adapt this centralized method into Federated Prejudice Remover.
#
# **Federated Prejudice Removal**: Each party applies the Prejudice Remover algorithm to train a less biased local model, and shares only the model parameters with the aggregator. The aggregator can then employ existing FL algorithms, like simple average and FedAvg, etc., to update the global model.
#
# Further details about the algorithms and datasets utilized, as well as experimental setup, are included in our [paper](https://arxiv.org/abs/2012.02447).

# %% [markdown]
# ## Fairness Metrics <a name="mnist"></a>
#
# In fairness evaluation, there is no single, all-inclusive metric. Literature uses multiple metrics to measure several aspects, painting a composition of fairness. We use four highly-utilized fairness metrics: Statistical Parity Difference, Equal Odds Difference, Average Odds Difference, and Disparate Impact.
#
# **Statistical Parity Difference**: Calculated as the ratio of the success rate between the unprivileged and privileged groups. The ideal value for this metric is 0, and the fairness range is between -0.1 and 0.1, as defined by [AI Fairness 360](https://aif360.mybluemix.net/).
#
# **Equal Odds Difference**: Calculated as the true positive rate difference between the unprivileged and privileged groups. The ideal value for this metric is 0, and the fairness range is between -0.1 and 0.1, similarly defined by AI Fairness 360.
#
# **Average Odds Difference**: Calculated as the mean of the false positive rate difference and the true positive rate difference, both between the unprivileged and privileged groups. The ideal value for this metric is 0, and the fairness range is between -0.1 and 0.1, similarly defined by AI Fairness 360.
#
# **Disparate Impact**: Calculated as the difference of the success rate between the unprivileged and privileged groups. The ideal value for this metric is 1, and the fairness range is between 0.8 and 1.2, similarly defined by AI Fairness 360.

# %% [markdown]
# ### Getting things ready
# We begin by setting the number of parties that will participate in the federated learning run and splitting up the data among them.

# %%
import sys
party_id = 0

sys.path.append('../..')
import os
os.chdir("../..")

num_parties = 2  ## number of participating parties
dataset = 'adult'

# %% [markdown]
# ## Parties
#
# Each party holds its own dataset that is kept to itself and used to answer queries received from the aggregator. Because each party may have stored data in different formats, FL offers an abstraction called Data Handler. This module allows for custom implementations to retrieve the data from each of the participating parties. A local training handler sits at each party to control the local training happening at the party side.

# %% [markdown]
# ### Party Configuration
#
# **Note**: in a typical FL setting, the parties may have very different configurations from each other. However, in this simplified example, the config does not differ much across parties. So, we first setup the configuration common to both parties, in the next cell. We discuss the parameters that are specific to each, in subsequent cells.

# %% [markdown]
# <img src="images/arch_party.png" width="680"/>
# <figcaption><center>Image Source: <a href="https://arxiv.org/pdf/2007.10987.pdf">IBM Federated Learning: An Enterprise FrameworkWhite Paper V0.1</a></center></figcaption>

# %% [markdown]
# ### Party Setup
# In the following cell, we setup configurations for parties, including network-level details, hyperparameters as well as the model specifications. Please note that if you are running this notebook in distributed environment on separate nodes then you need to split the data locally and obtain the model h5 generated by the Aggregator.

# %%
def get_party_config(party_id):
    party_config = {
        'aggregator':
            {
                'ip': '127.0.0.1',
                'port': 5000
            },
        'connection': {
            'info': {
                'ip': '127.0.0.1',
                'port': 8085 + party_id,
                'id': 'party' + str(party_id),
                'tls_config': {
                    'enable': False
                }
            },
            'name': 'FlaskConnection',
            'path': 'ibmfl.connection.flask_connection',
            'sync': False
        },
        'data': {
            'info': {
                'txt_file': 'examples/data/adult/random/data_party'+ str(party_id) +'.csv'
            },
            'name': 'AdultSklearnDataHandler',
            'path': 'ibmfl.util.data_handlers.adult_sklearn_data_handler'
        },
        'local_training': {
            'name': 'ReweighLocalTrainingHandler',
            'path': 'ibmfl.party.training.reweigh_local_training_handler'
        },
        'model': {
            'name': 'SklearnSGDFLModel',
            'path': 'ibmfl.model.sklearn_SGD_linear_fl_model',
            'spec': {
                'model_definition': 'examples/configs/sklearn_logclassification_rw/model_architecture.pickle',
            }
        },
        'protocol_handler': {
            'name': 'PartyProtocolHandler',
            'path': 'ibmfl.party.party_protocol_handler'
        }
    }
    return party_config

# %% [markdown]
# ### Running the Party
#
# Now, we invoke the `get_party_config` function to setup party and `start()` it.
#
# Finally, we register the party with the Aggregator.

# %%
from ibmfl.party.party import Party
import tensorflow as tf

party_config = get_party_config(party_id)
party = Party(config_dict=party_config)
party.start()
party.register_party()
party.proto_handler.is_private = False  ## allows sharing of metrics with aggregator
# Out:
# 2022-05-19 16:22:05,804 | 1.0.6 | INFO | ibmfl.util.config                             | Getting Aggregator details from arguments.
# 2022-05-19 16:22:06,399 | 1.0.6 | INFO | ibmfl.util.config                             | No metrics recorder config provided for this setup.
# 2022-05-19 16:22:06,748 | 1.0.6 | INFO | ibmfl.util.config                             | No metrics config provided for this setup.
# 2022-05-19 16:22:06,749 | 1.0.6 | INFO | ibmfl.util.config                             | No evidencia recordeer config provided for this setup.
# 2022-05-19 16:22:06,750 | 1.0.6 | INFO | ibmfl.util.data_handlers.adult_sklearn_data_handler | Loaded training data from examples/data/adult/random/data_party0.csv
# /Users/yi.zhou@ibm.com/Documents/ffl/FFL/ibmfl/util/data_handlers/adult_sklearn_data_handler.py:156: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_dataset['sex'] = training_dataset['sex'].map({' Female': 0, ' Male': 1})
# /Users/yi.zhou@ibm.com/Documents/ffl/FFL/ibmfl/util/data_handlers/adult_sklearn_data_handler.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   {' Asian-Pac-Islander': 0, ' Amer-Indian-Eskimo': 0, ' Other': 0, ' Black': 0, ' White': 1})
# /Users/yi.zhou@ibm.com/Documents/ffl/FFL/ibmfl/util/data_handlers/adult_sklearn_data_handler.py:161: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_dataset['class'] = training_dataset['class'].map({' <=50K': 0, ' >50K': 1})
# /Users/yi.zhou@ibm.com/Documents/ffl/FFL/ibmfl/util/data_handlers/adult_sklearn_data_handler.py:163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_dataset['age'] = training_dataset['age'].astype(int)
# /Users/yi.zhou@ibm.com/Documents/ffl/FFL/ibmfl/util/data_handlers/adult_sklearn_data_handler.py:164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_dataset['education-num'] = training_dataset['education-num'].astype(int)
# /Users/yi.zhou@ibm.com/Documents/ffl/FFL/ibmfl/util/data_handlers/adult_sklearn_data_handler.py:169: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_dataset['age' + str(i)] = 0
# /Users/yi.zhou@ibm.com/opt/anaconda3/envs/demo/lib/python3.6/site-packages/pandas/core/indexing.py:964: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# /Users/yi.zhou@ibm.com/Documents/ffl/FFL/ibmfl/util/data_handlers/adult_sklearn_data_handler.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_dataset['ed6less'] = 0
# 2022-05-19 16:22:07,075 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | RestSender initialized
# 2022-05-19 16:22:07,079 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Receiver Initialized
# 2022-05-19 16:22:07,080 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Initializing Flask application
# 2022-05-19 16:22:07,084 | 1.0.6 | INFO | ibmfl.party.party                             | Party initialization successful
# 2022-05-19 16:22:07,085 | 1.0.6 | INFO | ibmfl.party.party                             | Party start successful
# 2022-05-19 16:22:07,086 | 1.0.6 | INFO | ibmfl.party.party                             | Registering party...
# 2022-05-19 16:22:07,092 | 1.0.6 | INFO | werkzeug                                      |  * Running on http://127.0.0.1:8085/ (Press CTRL+C to quit)
# 2022-05-19 16:22:07,105 | 1.0.6 | INFO | ibmfl.party.party                             | Registration Successful
# 2022-05-19 16:22:44,322 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:44,324 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:44,326 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:44,326 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:44,329 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:44] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:44,333 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:44,344 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:44,348 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:44,392 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | No model update was provided.
# 2022-05-19 16:22:44,393 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:44,394 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:44,396 | 1.0.6 | WARNING | ibmfl.model.sklearn_SGD_linear_fl_model       | Obtaining class labels based on local dataset. This may cause failures during aggregation when parties have distinctive class labels.
# 2022-05-19 16:22:44,397 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:44,402 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:44,405 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:44,425 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:44,427 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:49,445 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:49,448 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:49,450 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:49,451 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:49,454 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:49] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:49,456 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:49,461 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:49,464 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:49,467 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:49,469 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:49,470 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:49,473 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:49,477 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:49,483 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:49,503 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:49,504 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:49,562 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:49,565 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:49,567 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:49,568 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:49,569 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:49] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:49,572 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:49,577 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:49,579 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:49,582 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:49,583 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:49,586 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:49,588 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:49,595 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:49,599 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:49,618 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:49,619 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:49,681 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:49,685 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:49,688 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:49,690 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:49,693 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:49] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:49,695 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:49,701 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:49,704 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:49,706 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:49,708 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:49,710 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:49,713 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:49,717 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:49,723 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:49,746 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:49,747 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:49,798 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:49,800 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:49,801 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:49,801 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:49,811 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:49,817 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:49,820 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:49,804 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:49] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:49,822 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:49,827 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:49,829 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:49,832 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:49,835 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:49,840 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:49,860 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:49,864 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:49,917 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:49,921 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:49,922 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:49,923 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:49,928 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:49] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:49,930 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:49,938 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:49,941 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:49,943 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:49,946 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:49,947 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:49,949 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:49,953 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:49,957 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:49,974 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:49,976 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:50,030 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:50,035 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:50,037 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:50,038 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:50,040 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:50] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:50,043 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:50,047 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:50,056 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:50,058 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:50,060 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:50,062 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:50,065 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:50,069 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:50,073 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:50,098 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:50,104 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:50,145 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:50,148 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:50,150 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:50,151 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:50,153 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:50] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:50,155 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:50,164 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:50,166 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:50,169 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:50,171 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:50,173 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:50,176 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:50,179 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:50,184 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:50,198 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:50,200 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:50,259 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:50,261 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:50,262 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:50,263 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:50,265 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:50] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:50,266 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:50,271 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:50,273 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:50,288 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:50,290 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:50,294 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:50,297 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:50,299 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:50,302 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:50,316 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:50,317 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:50,373 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:50,375 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:50,376 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:50,378 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:50] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:50,377 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:50,382 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:50,383 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:50,385 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:50,386 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:50,388 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:50,390 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:50,392 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:50,395 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:50,398 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:50,420 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:50,423 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:50,489 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:50,491 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:50,493 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:50,494 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:50,496 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:50] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:50,499 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:50,505 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:50,507 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:50,509 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:50,511 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:50,514 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:50,516 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:50,520 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:50,523 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:50,544 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:50,546 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:50,605 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:50,608 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:50,609 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:50,612 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:50] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:50,614 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:50,619 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:50,620 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:50,623 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:50,625 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:50,627 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:50,629 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:50,632 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:50,635 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:50,644 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:50,674 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:50,675 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:50,722 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:50,726 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:50,729 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:50,732 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:50] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:50,730 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:50,742 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:50,750 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:50,753 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:50,756 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:50,764 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:50,766 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:50,771 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:50,780 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:50,788 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:50,827 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:50,830 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:55,843 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:55,846 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:55,847 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:55,848 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:55,850 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:55] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:55,853 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:55,860 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:55,862 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:55,868 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:55,871 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:55,874 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:55,879 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:55,884 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:55,890 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:55,908 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:55,909 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:55,966 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:55,969 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:55,970 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:55,971 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:55,973 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:55] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:55,976 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:55,981 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:55,984 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:55,986 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:55,990 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:55,992 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:55,995 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:55,998 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:56,002 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:56,025 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:56,026 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:56,081 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:56,084 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:56,086 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:56,088 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:56,090 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:56] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:56,091 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:56,095 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:56,097 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:56,100 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:56,102 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:56,104 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:56,107 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:56,109 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:56,113 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:56,131 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:56,132 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:56,197 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:56,199 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:56,200 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:56,202 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:56,204 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:56] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:56,205 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:56,209 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:56,212 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:56,214 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:56,216 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:56,217 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:56,220 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:56,223 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:56,226 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:56,246 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:56,247 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:56,315 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:56,317 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:56,319 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:56,320 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:56,322 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:56] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:56,326 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:56,333 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:56,336 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:56,339 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:56,341 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:56,342 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:56,346 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:56,351 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:56,354 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:56,376 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:56,377 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:56,436 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:56,439 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:56,440 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:56,441 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:56,443 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:56] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:56,446 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:56,462 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:56,472 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:56,476 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:56,486 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:56,490 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# ...
# 2022-05-19 16:22:57,013 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:57,016 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:57,017 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:57,017 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:57,019 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:57] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:57,023 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:57,029 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:57,031 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:57,035 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:57,037 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:57,040 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:57,044 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:57,047 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:57,053 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:57,082 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:57,083 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:57,132 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:57,134 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:57,136 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:57,137 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:57,142 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:57] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:57,143 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:57,149 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:57,152 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:57,155 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:57,157 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:57,159 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:57,161 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:57,165 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:57,169 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:57,187 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:57,189 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:57,249 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:57,251 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:57,253 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:57,255 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:57,257 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:57] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:57,259 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:57,264 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:57,266 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:57,269 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:57,271 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:57,273 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:57,275 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:57,278 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:57,282 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:57,301 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:57,303 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:57,361 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:57,363 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:57,365 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:57,366 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:57,368 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:57] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:57,372 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:57,379 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:57,382 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:57,384 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:57,386 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:57,387 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:57,390 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:57,394 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:57,399 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:57,423 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:57,425 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:57,480 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:57,482 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:57,484 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:57,486 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:57,489 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:57] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:57,490 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:57,496 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:57,499 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:57,501 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:57,503 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:57,504 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:57,506 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:57,510 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:57,514 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:57,534 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:57,535 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:57,598 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:57,601 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:57,602 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:57,602 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:57,604 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:57] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:57,607 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:57,610 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:57,615 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:57,617 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:57,619 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:57,620 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:57,622 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:57,625 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:57,628 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:57,649 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:57,650 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-05-19 16:22:57,714 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-05-19 16:22:57,716 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-05-19 16:22:57,718 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-05-19 16:22:57,720 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-05-19 16:22:57,721 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [19/May/2022 16:22:57] "POST /7 HTTP/1.1" 200 -
# 2022-05-19 16:22:57,724 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-05-19 16:22:57,732 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-05-19 16:22:57,733 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-05-19 16:22:57,735 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-05-19 16:22:57,737 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training started...
# 2022-05-19 16:22:57,739 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Set warm_start as True
# 2022-05-19 16:22:57,741 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 1:
# 2022-05-19 16:22:57,748 | 1.0.6 | INFO | ibmfl.model.sklearn_SGD_linear_fl_model       | Local training epoch 2:
# 2022-05-19 16:22:57,752 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | Local training done, generating model update...
# 2022-05-19 16:22:57,774 | 1.0.6 | INFO | ibmfl.party.training.reweigh_local_training_handler | {'score': 0.675, 'acc': 0.675, 'f1': 0.0, 'precision': 0.0, 'recall': 0.0, 'average precision': 0.32, 'roc auc': 0.5, 'negative log loss': 11.23, 'Fairness Report': {'F1': 0.0, 'Statistical Parity Difference:': 0.0, 'Equal Opportunity Difference': 0.0, 'Average Odds Difference:': 0.0, 'Disparate Impact:': 0}, 'Underestimation Index': 0.7071067811865476}
# 2022-05-19 16:22:57,775 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request

# %% [markdown]
# ## Register All Parties Before Starting Training
#
# Now we have started and registered this Party. Next, we will start and register rest of the parties. Once all the Parties have registered we will go back to the Aggregator's notebook to start training.

# %% [markdown]
# ## Results
#
# We utilize these methods in our paper, and share below our experimental results for Local Reweighing and Federated Prejudice Remover on the Adult Dataset. Using 8 parties and a global testing set, we find both methods to be effective in reducing bias as measured by these four fairness metrics. Local reweighing is particularly effective.
#
# <img src="images/adult8P.png" width="720"/>
# <figcaption><center>Fairness Metrics for Local Reweighing and Federated Prejudice Remover on 8 Party Adult Dataset Experiment</a></center></figcaption>

# %% [markdown]
# ## Shut Down
#
# Invoke the `stop()` method on each of the network participants to terminate the service.

# %%
party.stop()
# Out:
# 2020-10-03 23:07:38,861 -STD ibmfl.connection.flask_connection - INFO - Stopping Receiver and Sender
# 2020-10-03 23:07:38,867 -STD werkzeug - INFO - 127.0.0.1 - - [03/Oct/2020 23:07:38] "POST /shutdown HTTP/1.1" 200 -
# 2020-10-03 23:07:38,869 -STD ibmfl.party.party - INFO - Party stop successful
