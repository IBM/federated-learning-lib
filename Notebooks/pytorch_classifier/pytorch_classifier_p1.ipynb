# %% [markdown]
# # PyTorch MNIST classifier in IBM FL

# %% [markdown]
# ## Outline:
# - [Add conda environment to Jupyter Notebook](#setup)
# - [Federated Learning(FL)](#intro)
# - [Digit Recognition](#mnist)
# - [Parties](#Parties)
#     - [Party Configuration](#Party-Configuration)
#     - [Party Setup](#Party-Setup)
# - [Register All Parties Before Starting Training](#Register-All-Parties-Before-Starting-Training)
# - [Visualize Results](#Visualize-Results)
# - [Shut Down](#Shut-Down)

# %% [markdown]
# ## Add conda environment to Jupyter Notebook <a name="setup"></a>
#
# Please ensure that you have activated the `conda` environment following the instructions in the project README.
#
# Once done, run the following commands in your terminal to install your conda environment into the Jupyter Notebook:
#
# 1. Once you have activated the conda environment, install the `ipykernel` package: `conda install -c anaconda ipykernel`
#
# 2. Next, install the `ipykernel` module within Jupyter Notebook: `python -m ipykernel install --user --name=<conda_env>`
#
# 3. Please install the `matplotlib` package for your conda environment.
#
# 4. Finally, restart the jupyter notebook once done. Ensure that you are running this Notebook from `<project_path>/Notebooks`, where project_path is the directory where the IBMFL repository was cloned.
#
# When the Notebook is up and running it may prompt you to choose the kernel. Use the drop down to choose the kernel name same as that chosen when running `conda activate <conda_env>`. If no prompt shows up, you can change the kernel by clicking _Kernel_ > _Change kernel_ > _`<conda_env>`_.

# %% [markdown]
# ## Federated Learning (FL) <a name="intro"></a>
#
# **Federated Learning (FL)** is a distributed machine learning process in which each participant node (or party) retains their data locally and interacts with  other participants via a learning protocol.
# One main driver behind FL is the need to not share data with others  due to privacy and confidentially concerns.
# Another driver is to improve the speed of training a machine learning model by leveraging other participants' training processes.
#
# Setting up such a federated learning system requires setting up a communication infrastructure, converting machine learning algorithms to federated settings and in some cases knowing about the intricacies of security and privacy enabling techniques such as differential privacy and multi-party computation.
#
# In this Notebook, we use [IBM FL](https://github.com/IBM/federated-learning-lib) to have multiple parties train a classifier to recognise handwritten digits in the [MNIST dataset](http://yann.lecun.com/exdb/mnist/). Our focus is on a [PyTorch](https://pytorch.org/) model.
#
# For a more technical dive into IBM FL, refer the whitepaper [here](https://arxiv.org/pdf/2007.10987.pdf).

# %% [markdown]
# In the following cells, we set up each of the components of a Federated Learning network (See Figure below) wherein all involved parties aid in training their respective local cartpoles to arrive at the upright pendulum state. In this notebook we default to 5 parties, but depending on your resources you may use fewer parties.
#
# <img style="display=block; margin:auto" src="../images/FL_Network.png" width="720"/>
# <p style="text-align: center">Modified from Image Source: <a href="https://arxiv.org/pdf/2007.10987.pdf">IBM Federated Learning: An Enterprise FrameworkWhite Paper V0.1</a></p>

# %% [markdown]
# ## Digit Recognition <a name="mnist"></a>

# %% [markdown]
# <img style="display=block; margin:auto" src="../images/MnistExamples.png" width="512"/>
# <p style="text-align: center">Image Source: Josef Steppan / CC BY-SA <a href="https://creativecommons.org/licenses/by-sa/4.0">Wikimedia Commons</a></p>

# %% [markdown]
# The problem at hand is to recognize digits from these tens of thousands of handwritten images.

# %% [markdown]
# ### Getting things ready
# We begin by setting the number of parties that will participate in the federated learning run and splitting up the data among them.

# %%
import sys
party_id = 1

sys.path.append('../..')
import os
os.chdir("../..")

num_parties = 2  ## number of participating parties
dataset = 'mnist'

# %% [markdown]
# ## Parties
#
# Each party holds its own dataset that is kept to itself and used to answer queries received from the aggregator. Because each party may have stored data in different formats, FL offers an abstraction called Data Handler. This module allows for custom implementations to retrieve the data from each of the participating parties. A local training handler sits at each party to control the local training happening at the party side.

# %% [markdown]
# ### Party Configuration
#
# **Note**: in a typical FL setting, the parties may have very different configurations from each other. However, in this simplified example, the config does not differ much across parties. So, we first setup the configuration common to both parties, in the next cell. We discuss the parameters that are specific to each, in subsequent cells.

# %% [markdown]
# <img style="display=block; margin:auto" src="../images/arch_party.png" width="680"/>
# <p style="text-align: center">Image Source: <a href="https://arxiv.org/pdf/2007.10987.pdf">IBM Federated Learning: An Enterprise FrameworkWhite Paper V0.1</a></p>

# %% [markdown]
# ### Party Setup
# In the following cell, we setup configurations for parties, including network-level details, hyperparameters as well as the model specifications. Please note that if you are running this notebook in distributed environment on separate nodes then you need to split the data locally and obtain the model h5 generated by the Aggregator.

# %% [markdown]
# #### Building Blocks in Party Configuration:
#
# Now we configure party specific configurations in the `get_party_config` method, which specifies model related configurations as well as other parameters necessary for the federated learning setup. The model related configurations are identical to those generated (yaml files) during the terminal run.
#
# Once these are done, we invoke them for each party, in the subsequent cell.
#
# - `local_training_handler`: handles the train and eval commands, also initializes data, environment and models
#
# - `protocol_handler`: party protocol handler communicates with the Aggregator bridging between Aggregator and local training handler
#
# - `aggregator`: IP and port at which the Aggregator is running, so the party may connect to it
#
# - `data`: information needed to initiate a data handler class; includes a given data path, a data handler class name, and a data handler file location
#
# - `model`: details about the model, including name, the model class file location, i.e., path, and the given model specification path, i.e., spec. In this example, we use the PyTorch FL Model class, as indicated under the spec. (It is worth mentioning that IBMFL uses a [Skorch](https://skorch.readthedocs.io/en/stable/) model class as a wrapper on top of PyTorch models. However, the user does not need to worry about the details when deploying PyTorch models.)
#
# **Note**: in a typical FL setting, the parties may have very different configurations from each other. However, in this simplified example, the config does not differ much across parties. Also, as of this release all parties registered with the aggregator participate in the training. Dynamically letting registered parties to skip training in certain rounds will be supported in subsequent versions.

# %%
def get_party_config(party_id):
    party_config = {
        'aggregator':
            {
                'ip': '127.0.0.1',
                'port': 5000
            },
        'connection': {
            'info': {
                'ip': '127.0.0.1',
                'port': 8085 + party_id,
                'id': 'party' + str(party_id),
                'tls_config': {
                    'enable': False
                }
            },
            'name': 'FlaskConnection',
            'path': 'ibmfl.connection.flask_connection',
            'sync': False
        },
        'data': {
            'info': {
                'npz_file': 'examples/data/mnist/random/data_party'+ str(party_id) +'.npz'
            },
            'name': 'MnistPytorchDataHandler',
            'path': 'ibmfl.util.data_handlers.mnist_pytorch_data_handler'
        },
        'local_training': {
            'name': 'LocalTrainingHandler',
            'path': 'ibmfl.party.training.local_training_handler'
        },
        'model': {
            'name': 'PytorchFLModel',
            'path': 'ibmfl.model.pytorch_fl_model',
            'spec': {
                'model_definition': 'examples/configs/iter_avg/pytorch/pytorch_sequence.pt',
                'model_name': 'pytorch-cnn',
                'optimizer': 'optim.Adam',
                'criterion': 'nn.NLLLoss',
            }
        },
        'protocol_handler': {
            'name': 'PartyProtocolHandler',
            'path': 'ibmfl.party.party_protocol_handler'
        }
    }
    return party_config

# %% [markdown]
# ### Running the Party
#
# Now, we invoke the `get_party_config` function to setup party and `start()` it.
#
# Finally, we register the party with the Aggregator.

# %%
from ibmfl.party.party import Party
import tensorflow as tf

party_config = get_party_config(party_id)
party = Party(config_dict=party_config)
party.start()
party.register_party()
party.proto_handler.is_private = False  ## allows sharing of metrics with aggregator
# Out:
# 2022-03-10 12:59:12,479 | 1.0.6 | INFO | ibmfl.util.config                             | Getting Aggregator details from arguments.
# 2022-03-10 12:59:12,786 | 1.0.6 | INFO | ibmfl.util.config                             | No metrics recorder config provided for this setup.
# 2022-03-10 12:59:13,605 | 1.0.6 | INFO | ibmfl.util.config                             | No metrics config provided for this setup.
# 2022-03-10 12:59:13,606 | 1.0.6 | INFO | ibmfl.util.config                             | No evidencia recordeer config provided for this setup.
# 2022-03-10 12:59:13,607 | 1.0.6 | INFO | ibmfl.util.data_handlers.mnist_pytorch_data_handler | Loaded training data from examples/data/mnist/random/data_party1.npz
# 200 train samples
# 5000 test samples
# y_train shape: (200,)
# 200 train samples
# 5000 test samples
# 2022-03-10 12:59:13,661 | 1.0.6 | INFO | ibmfl.model.pytorch_fl_model                  | No loss criterion found in the config file. Using default NLLLoss.
# 2022-03-10 12:59:13,663 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | RestSender initialized
# 2022-03-10 12:59:13,667 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Receiver Initialized
# 2022-03-10 12:59:13,668 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Initializing Flask application
# 2022-03-10 12:59:13,672 | 1.0.6 | INFO | ibmfl.party.party                             | Party initialization successful
# 2022-03-10 12:59:13,673 | 1.0.6 | INFO | ibmfl.party.party                             | Party start successful
# 2022-03-10 12:59:13,674 | 1.0.6 | INFO | ibmfl.party.party                             | Registering party...
# 2022-03-10 12:59:13,680 | 1.0.6 | INFO | werkzeug                                      |  * Running on http://127.0.0.1:8086/ (Press CTRL+C to quit)
# 2022-03-10 12:59:13,699 | 1.0.6 | INFO | ibmfl.party.party                             | Registration Successful
# 2022-03-10 12:59:21,315 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-03-10 12:59:21,317 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-03-10 12:59:21,317 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-03-10 12:59:21,318 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-03-10 12:59:21,319 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [10/Mar/2022 12:59:21] "POST /7 HTTP/1.1" 200 -
# 2022-03-10 12:59:21,320 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-03-10 12:59:21,321 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-03-10 12:59:21,322 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-03-10 12:59:21,323 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | No model update was provided.
# 2022-03-10 12:59:21,324 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local training started...
#   epoch    train_loss     dur
# -------  ------------  ------
#       1        2.7146  0.4040
#       2        2.3155  0.3701
#       3        2.2507  0.3792
# 2022-03-10 12:59:22,497 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local training done, generating model update...
# 2022-03-10 12:59:25,009 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | {'accuracy_score': 0.1854}
# 2022-03-10 12:59:25,009 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-03-10 12:59:26,543 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-03-10 12:59:26,584 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-03-10 12:59:26,585 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-03-10 12:59:26,586 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-03-10 12:59:26,586 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [10/Mar/2022 12:59:26] "POST /7 HTTP/1.1" 200 -
# 2022-03-10 12:59:26,587 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-03-10 12:59:26,588 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-03-10 12:59:26,589 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-03-10 12:59:26,591 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-03-10 12:59:26,592 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local training started...
#       4        2.1468  0.3449
#       5        1.9540  0.3501
#       6        1.5904  0.3476
# 2022-03-10 12:59:27,645 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local training done, generating model update...
# 2022-03-10 12:59:29,972 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | {'accuracy_score': 0.5846}
# 2022-03-10 12:59:29,973 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-03-10 12:59:31,793 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-03-10 12:59:31,831 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-03-10 12:59:31,832 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-03-10 12:59:31,832 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-03-10 12:59:31,834 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [10/Mar/2022 12:59:31] "POST /7 HTTP/1.1" 200 -
# 2022-03-10 12:59:31,834 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-03-10 12:59:31,836 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-03-10 12:59:31,836 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-03-10 12:59:31,839 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-03-10 12:59:31,840 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local training started...
#       7        1.3623  0.3531
#       8        1.1271  0.3586
#       9        0.9342  0.3578
# 2022-03-10 12:59:32,920 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local training done, generating model update...
# 2022-03-10 12:59:35,261 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | {'accuracy_score': 0.7918}
# 2022-03-10 12:59:35,262 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-03-10 12:59:37,028 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-03-10 12:59:37,064 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-03-10
| 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | {'accuracy_score': 0.8846}
# 2022-03-10 13:00:17,111 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request
# 2022-03-10 13:00:18,944 | 1.0.6 | INFO | ibmfl.connection.flask_connection             | Request received for path :7
# 2022-03-10 13:00:18,984 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | received a async request
# 2022-03-10 13:00:18,985 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | finished async request
# 2022-03-10 13:00:18,985 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Handling async request in a separate thread
# 2022-03-10 13:00:18,986 | 1.0.6 | INFO | werkzeug                                      | 127.0.0.1 - - [10/Mar/2022 13:00:18] "POST /7 HTTP/1.1" 200 -
# 2022-03-10 13:00:18,987 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request from aggregator
# 2022-03-10 13:00:18,988 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in with message_type:  7
# 2022-03-10 13:00:18,989 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | Received request in PH 7
# 2022-03-10 13:00:18,992 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local model updated.
# 2022-03-10 13:00:18,992 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local training started...
#      34        0.0788  0.3535
#      35        0.1286  0.3443
#      36        0.1365  0.3427
# 2022-03-10 13:00:20,045 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | Local training done, generating model update...
# 2022-03-10 13:00:22,427 | 1.0.6 | INFO | ibmfl.party.training.local_training_handler   | {'accuracy_score': 0.8848}
# 2022-03-10 13:00:22,428 | 1.0.6 | INFO | ibmfl.party.party_protocol_handler            | successfully finished async request

# %% [markdown]
# ## Register All Parties Before Starting Training
#
# Now we have started and registered this Party. Next, we will start and register rest of the parties. Once all the Parties have registered we will go back to the Aggregator's notebook to start training.

# %% [markdown]
# ## Visualize Results
#
# Here we plot the summary graphs from each party's training.

# %%
import torch
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
from sklearn.metrics import accuracy_score
from ibmfl.util.data_handlers.mnist_pytorch_data_handler \
   import MnistPytorchDataHandler

sample_count = 100
num_parties = 1
mnist_data_handler = MnistPytorchDataHandler()
_, testdata = mnist_data_handler.get_data()
X_test, Y_test = testdata[0], testdata[1]
for i in range(10):
   test_filter = np.where(Y_test == i)
   X_test1, Y_test1 = X_test[test_filter], Y_test[test_filter]
   #labels, counts = np.unique(Y_test1, return_counts=True)
   np.random.seed(123)
   rand_v = np.random.randint(0, X_test1.shape[0],sample_count)
   test_digits = X_test1[rand_v]
   test_labels = Y_test1[rand_v]
   labels, counts = np.unique(test_labels, return_counts=True)
   #print('Original lable', labels)
   acc_list = np.array([])
   y_true = np.full(sample_count, i)
    
   y_pred = np.array([])
   for i_samples in range(sample_count):
      pred = party.fl_model.predict(
         torch.unsqueeze(torch.from_numpy(test_digits[i_samples]),0))
      y_pred = np.append(y_pred, pred.argmax())
   acc = accuracy_score(y_true, y_pred) * 100
   #print('y prediction',y_pred)
   #print('y true',y_true)
   #print('accuracy',acc)
   acc_list = np.append(acc_list,acc)

   ind = np.arange(num_parties) 
   fig2 = plt.figure(constrained_layout=True,figsize=(10,10))
   fig2.tight_layout()
   spec2 = gridspec.GridSpec(ncols=6, nrows=4, figure=fig2) 
   f2_ax1 = fig2.add_subplot(spec2[0:1, 0:2])
   f2_ax1.imshow(np.squeeze(test_digits[0]), cmap='gray')
   plt.axis('off')
   f2_ax2 = fig2.add_subplot(spec2[0:1, 3:])
   labels = [(i+1) for i in range(num_parties)] 
   
   x = np.arange(num_parties)
  

   rects1 = f2_ax2.bar(x, acc_list, width=0.3)
   # Add some text for labels, title and custom x-axis tick labels, etc.
   f2_ax2.set_xlabel('Party ' + str(party_id))
   f2_ax2.set_ylabel('Average Prediction Accuracy \n over '+str(sample_count)+' samples')
   f2_ax2.set_title('Average Prediction Accuracy by parties for label '+str(i))
   f2_ax2.set_xticks(x)
   f2_ax2.set_xticklabels(labels)
# Out:
# 500 train samples
# 500 test samples
# y_train shape: (500,)
# 500 train samples
# 500 test samples

# %% [markdown]
# ## Shut Down
#
# Invoke the `stop()` method on each of the network participants to terminate the service.

# %%
party.stop()
